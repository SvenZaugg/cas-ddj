# %%
def print_two(*args):
    arg1, arg2 = args
    print(f'arg1: {arg1}, arg2: {arg2}')
    
def print_two_again(arg1, arg2):
    print(f'arg1: {arg1}, arg2: {arg2}')
          
def print_one(arg1):
    print(f'arg1: {arg1}')

def print_none():
    print('I got nothin.')
          
print_two('Sven','Zaugg')
print_two_again('Sven','Zaugg')
print_one('First!')
print_none()

# %%
#hier schreiben wir die funktion = wir sagen 
def cheese_and_crackers(cheese_count, boxes_of_crackers):
    print(f'you have {cheese_count} cheeses!')
    print(f'You have {boxes_of_crackers} boxes of crackers!')
    print('Man thats enough for a party!')
    print('Get a blanket.\n')

print('We can just give the function numbers directly:')
cheese_and_crackers(20,30)

print('OR, we can variables from our script:')
amount_of_cheese = 10
amount_of_crackers = 50

cheese_and_crackers(amount_of_cheese, amount_of_crackers)

print('We can even do math inside too:')
cheese_and_crackers(10 + 20, 5 + 6)

print('And we can combine th two, variables and math')
cheese_and_crackers(amount_of_cheese + 100, amount_of_crackers + 1000)

# %%
def new_home(room_count, quantity_people):
    print(f'you have {room_count} rooms!')
    print(f'You have {quantity_people} that many people!')
    print('Man thats enough for a party!')
    print('Fuck you.\n')
    
print('We can just give the function numbers directly:')
new_home(20,30)

print('OR, we can variables from our script:')
amount_of_room = 10
amount_of_people = 50

new_home(room_count, quantity_people)

print('We can even do math inside too:')
new_home(10 + 20, 5 + 6)

print('And we can combine th two, variables and math')
new_home(amount_of_room + 100, amount_of_people + 1000)

# %%
def add(a,b):
    print(f'ADDING {a} + {b}')
    return(a + b)
    

def subtract(a,b):
    print(f'SUBTRACTING {a} - {b}')
    return(a - b)
    

def multiply(a,b):
    print(f'MULTIPLY {a} * {b}')
    return(a * b)


def divide(a,b):
    print(f'DIVIDING {a} / {b}')
    return(a / b)
    

print('Lets do some math with just functions!')

age = add(30,5)
height = subtract(78,4)
weight = multiply(90,2)
iq = divide(100,2)

print(f'Age: {age}, Height: {height}, Weight: {weight}, IQ: {iq}')

print('Here is a puzzle')

what = add(age, subtract(height, multiply(weight, divide(iq,2))))

print('That becomes: ', what, 'Can you do it by hand?')

# %%
#boolean practice
True and True
False and False
1 == 1 and 2 == 1
'test' == 'test'
1 == 1 or 2 != 1

# %%
people = 20
cats = 30
dogs = 15
    
if people < cats:
    print('great')    

if people > cats:
    print('so sad')

if people < dogs:
    print('I hate dogs')
    
if people > dogs:
    print('I hate people')
    
dogs += 5

if people >= dogs:
    print('people are greater or equal to dogs')
    
if people <= dogs:
    print('people are less that or equal to dogs')

if people == dogs:
    print('people are dogs')

# %%
#mit if sagen wir wenn, mit elif geben wir eine zweit kondition an; also auch wenn. mit else sagen wir;
#mit else sagen wir: das ist das resultat, falls beides (if und elif) nicht zutrifft.

#check boolean expressions!

people = 30
cars = 40
trucks = 15

#hier sagen wir: wenn cars grösser ist als people, dann print. 
if cars == people:
#hier sagen wir. wenn cars kleiner ist als people, dann print
    print('We should take the cars.')
elif cars <= people:
    print('we should not take the cars')
#hier sagen wir: wenn beides nicht zutrifft, dann print.
else:
    print('we cant decide')

if trucks > cars:
    print('thats too many trucks')
elif trucks < cars:
    print('maybe we could take the trucks')
else:
    print('we still cant decide')

if people > trucks:
    print('alright, lets just take the trucks')
else:
    print('fine, lets stay home then')

# %%
print('you enter a dark room with two doors. do you go through door #1 or door #2 or door #3?')

door = input('')

if door == '1':
    print('theres a giant bear here eating a cake.')
    print('what do you do?')
    print('1. take the cake.')
    print('2. scream at the bear.')

    bear = input('')

    if bear == '1':
        print('the bear eats your face off. good job!')
    elif bear == '2':
        print('the bear eats your legs off. good job!')
    else:
        print(f'well, doing {bear} is probably better.')
        print('bear runs away.')
    
elif door == '2':
    print('you stare into the endless abyss.')
    print('1. blueberries.')
    print('2. yellow jacket.')
    print('3. shit!')
    
    insanity = input('')
    
    if insanity == '1' or insanity == '2':
        print('your body survives powered by a mind of jello')
        print('good job!')
    else:
        print('the insanity rot your eyes into a pool of much.')
        print('good job')
        
elif door == '3':
    print('eat your own shit.')
    print('1. dildo.')
    print('2. snowboard.')
    print('3. car!')
    
    insanity = input('')
    
    if insanity == '1' or insanity == '2' or insanity == '3':
        print('your body survives powered cocain')
        print('good job!')
    else:
        print('the insanity makes you cry.')
        print('good job')
        
else: 
    print('you stumble around an fall an a knife an die. good job!')

# %%
print('du hast die wahl. entscheidest du dich für ein spannendes leben #a oder für ein langweiliges #b?')

leben = input('')

if leben == 'a':
    print('das ist die richtige entscheidung!')
    print('warum hast du dich dafür entschieden?')
    print('1. weil ichs geil find')
    print('2. weil ich hier was sagen muss')
 
    love = input('')

    if love == 'a':
        print('liebe ist das wichtigste')
    elif love == 'b':
        print('ohne liebe ist das leben langweilig')
    else:
        print(f'na dann, {love}.')
        print('ist doch eh alles scheissegal.')

elif leben == 'b':
    print('du bist ein armer tropf.')
    print('1. erschiess dich gleich selbst.')
    print('2. hol dir drogen.')
    print('3. weine!')
    
    alkohol = input('')
    
    if alkohol == 'a' or alkohol == 'b':
        
        print('saufen hilft immer')
        print('tolle entscheidung!')
    else:
        print('du hast ja die nummer des dealers')
        print('pfff')

# %%
#loops and lists

the_count = [1, 2, 3, 4, 5]
fruits = ['apples', 'oranges', 'pears', 'apricots']
change = [1, 'pennies', 2, 'dimes', 3, 'quarters']

#der loop geht in der liste the_count über jede zahl
for number in the_count:
    print(f'This is count {number}')
    
#der loop geht in der liste fruit über jede frucht
for fruit in fruits:
    print(f'A fruit of type: {fruit}')
    
for i in change:
    print(f'I got {i}')
    
elements = []

for i in range (0,6):
    print(f'ADDING {i} to the list.')
    elements.append(i)

for i in elements:
    print(f'Element was: {i}')

# %%
#Artikel, die zwischen 0 und 20 (einschließlich) CHF kosten, werden um 20 % reduziert;
#Artikel, die zwischen 20 (nicht einschließlich) und 50 CHF (einschließlich) kosten, werden um 40 % reduziert.
#Alle anderen Artikel, also solche, die mehr als 50 CHF kosten, werden um 60 % reduziert.

price = 20

if price <= 20:
    print(str(price*0.8))
elif price <= 50:
    print(str(price*0.6))
else:
    print(str(price*0.4))

# %%
text = 'Der US-Luftfahrtriese Boeing ordnet seine Führungsetage im Zuge der Krise um den nach zwei Abstürzen mit Startverboten belegten Flugzeugtyp 737 Max neu. Dennis Muilenburg wird den Verwaltungsratsvorsitz abgeben, wie der Konzern am Freitagabend in Chicago mitteilte. Er soll sich stattdessen als Vorstandschef in Vollzeit um die angestrebte Wiederzulassung der 737 Max, die Bedürfnisse der Kunden und die Verschärfung von Boeings Fokus auf Produkt- und Service-Sicherheit kümmern können.'

# %%
words = (len(text.split()))
print("Der Artikel enthält", '' +str(words), '' +"Wörter")

# %%
mail = "zoe.gwerder@zugerzeitung.ch"
real_name = mail.split('@')

print(real_name)

# %%
dotfree = real_name[0].split('.')
name = ''.join(dotfree)

print(name)

# %%
mail1 = "zarah.zauber@zauberberg.de"
mail2 = "thomas.plotkowiak@gmail.com"
mail3 = "uwe_unhold@dunklerwald.de" 

list = []
list.append(mail1.split('@')[0]) 
list.append(mail2.split('@')[0])
list.append(mail2.split('@')[0])

print('Wir haben aktuell' + str(len(list)) + 'Kunden im System. \nDas sind:\n' + '\n'.join(list))

# %%
country = "US"
age = 21

if age < 21 and country == "US":
    print("Du darfst kein Bier trinken")
elif age >= 21 and country == "US":
    print("Du darfst Bier trinken")
# Out:
# Du darfst Bier trinken

# %%
#Branches and Functions

from sys import exit

def gold_room():
    print('This room is full of gold. How much do you take?')

    choice = input('> ')
    
    if '0' in choice or '1' in choice:
        how_much = int(choice)
    else:
        dead('Man, learn to type a number.')
        
    if how_much < 50:
        print('Nice, youre not greedy, you win!')
        exit(0)
    else:
        dead('You greedy bastard!')
        
def bear_room():
    print('There is a bear here.')
    print('The bear has a bunch of honey')
    print('The fat bear is in front of another door.')
    print('How are you going to move the bear?')
    
    bear_moved = False
    
    while True:
        choice = input('> ')
        
        if choice == 'take honey':
            dead('The bear looks at you then slaps your face off.')
        elif choice == 'taunt bear'and not bear_moved:
            print('The bear has moved from the door')
            print('You can go through it now.')
            bear_moved = True
        elif choice == 'taunt bear' and bear_moved:
            dead('The bear gets pissed offf and chews your leg off.')
        elif choice == 'open door' and bear_moved:
            gold_room()
        else:
            print('I got no idea waht that means')
                
def cthulhu_room():
    print('Here you see the great evil Cthulhu.')
    print('He, it, whatever stares at you and you go insane.')
    print('Do you flee for your life or eat your head')
    
    choice = input('> ')
    
    if 'flee' in choice:
        start()
    elif 'head' in choice:
        dead('Well that was tasty!')
    else:
        cthulhu_room()
        
def dead(why):
    print(why, 'Good job!')
    exit(0)
    
def start():
    print('You are in a dark room.')
    print('There is a door to your right and left.')
    print('Which one do you take?')
    
    choice = input('> ')
    
    if choice == 'left':
        bear_room()
    elif choice == 'right':
        cthulhu_room()
    else:
        dead('You stumble around the room until you starve')
        
start()
# Out:
# You are in a dark room.
# There is a door to your right and left.
# Which one do you take?
# > right
# Here you see the great evil Cthulhu.
# He, it, whatever stares at you and you go insane.
# Do you flee for your life or eat your head
# > flee
# You are in a dark room.
# There is a door to your right and left.
# Which one do you take?
# > right
# Here you see the great evil Cthulhu.
# He, it, whatever stares at you and you go insane.
# Do you flee for your life or eat your head
# > flee
# You are in a dark room.
# There is a door to your right and left.
# Which one do you take?
# > left
# There is a bear here.
# The bear has a bunch of honey
# The fat bear is in front of another door.
# How are you going to move the bear?
# > move
# I got no idea waht that means
# > yes
# I got no idea waht that means
# > move
# I got no idea waht that means
